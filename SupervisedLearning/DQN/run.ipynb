# %%
from DQN import is_atari_env, train_atari, train_cartpole
from plots import plot_training
from config import Config

# %%
cfg = Config()

if is_atari_env(cfg.env_id):
    episode_rewards, episode_epsilons, losses = train_atari()
    plot_training(episode_rewards, episode_epsilons, losses, title_prefix=f"DQN Atari ({cfg.env_id})")
else:
    episode_rewards, episode_epsilons, losses = train_cartpole()
    plot_training(episode_rewards, episode_epsilons, losses, title_prefix=f"DQN ({cfg.env_id})")
# Out:
# [Atari] device: cuda
# Ep 0001 | step=   1471/10000 | R= 1660.0 | avg20= 1660.0 | eps=0.972 | replay=1471
# Ep 0002 | step=   2093/10000 | R=  530.0 | avg20= 1095.0 | eps=0.960 | replay=2093
# Ep 0003 | step=   2691/10000 | R=  630.0 | avg20=  940.0 | eps=0.949 | replay=2691
# Ep 0004 | step=   3902/10000 | R= 1180.0 | avg20= 1000.0 | eps=0.926 | replay=3902
# Ep 0005 | step=   4221/10000 | R=  310.0 | avg20=  862.0 | eps=0.920 | replay=4221
# Ep 0006 | step=   5141/10000 | R= 1080.0 | avg20=  898.3 | eps=0.902 | replay=5141
# Ep 0007 | step=   5983/10000 | R= 1030.0 | avg20=  917.1 | eps=0.886 | replay=5983
# Ep 0008 | step=   7350/10000 | R= 1300.0 | avg20=  965.0 | eps=0.860 | replay=7350
# Ep 0009 | step=   8507/10000 | R= 1300.0 | avg20= 1002.2 | eps=0.838 | replay=8507
# Ep 0010 | step=   9935/10000 | R= 1300.0 | avg20= 1032.0 | eps=0.811 | replay=9935
